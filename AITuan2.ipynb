# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenTanPhat20146511/B-i-t-p-Robot/blob/main/AITuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'

# %%
data=pd.read_csv(url)
data[data['NOC']=='CAN'].head(2300)
# Out:
#       Year         City       Sport       Discipline  NOC            Event  \
# 4     1924     Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# 54    1928   St. Moritz  Ice Hockey       Ice Hockey  CAN       ice hockey
# 92    1932  Lake Placid  Ice Hockey       Ice Hockey  CAN       ice hockey
# 93    1932  Lake Placid     Skating   Figure skating  CAN       individual
# 94    1932  Lake Placid     Skating    Speed skating  CAN           10000m
# ...    ...          ...         ...              ...  ...              ...
# 2105  2006        Turin     Skating    Speed skating  CAN     Team pursuit
# 2106  2006        Turin      Skiing  Cross Country S  CAN     Sprint 1.5km
# 2107  2006        Turin      Skiing  Cross Country S  CAN      Team sprint
# 2108  2006        Turin      Skiing   Freestyle Ski.  CAN           moguls
# 2109  2006        Turin      Skiing        Snowboard  CAN  Snowboard Cross
#
#      Event gender   Medal
# 4               M    Gold
# ...

# %%
print('So huy chuong vang')
data[(data['NOC']=='CAN') & (data['Medal']=='Gold')].drop(data.columns[0:7],axis=1).count()
# Out:
# So huy chuong vang
# Medal    38
# dtype: int64
